# %%
import pandas as pd

# %%
data = pd.read_csv('files/titanic.csv')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#transpose

# %%
data.T
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age         22       38      26      35    35     NaN       54       2
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
data.transpose()
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age         22       38      26      35    35     NaN       54       2
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataT = data.transpose()

# %%
dataT.head()
# Out:
#            0       1       2       3     4     5     6     7       8    \
# survived     0       1       1       1     0     0     0     0       1
# pclass       3       1       3       1     3     3     1     3       3
# sex       male  female  female  female  male  male  male  male  female
# age         22      38      26      35    35   NaN    54     2      27
# sibsp        1       1       0       1     0     0     0     3       0
#
#              9    ...   881     882   883   884     885   886     887     888  \
# survived       1  ...     0       0     0     0       0     0       1       0
# pclass         2  ...     3       3     2     3       3     2       1       3
# sex       female  ...  male  female  male  male  female  male  female  female
# age           14  ...    33      22    28    25      39    27      19     NaN
# sibsp          1  ...     0       0     0     0       0     0       0       1
#
#            889   890
# survived     1     0
# pclass       1     3
# ...

# %%
dataT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, survived to deck
# Columns: 891 entries, 0 to 890
# dtypes: object(891)
# memory usage: 63.0+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
dataT.T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    object
#  2   sex       891 non-null    object
#  3   age       714 non-null    object
#  4   sibsp     891 non-null    object
#  5   parch     891 non-null    object
#  6   fare      891 non-null    object
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: object(9)
# memory usage: 62.8+ KB

# %%
dataTagain = dataT.T

# %%
#problem with dtype

# %%
dataTagain['survived'].mean()
# Out:
# 0.3838383838383838

# %%
sexPclass = dataTagain.groupby(['sex','pclass'])

# %%
#sexPclass['survived'].mean() #will return error if transpose same dataFrame two times

# %%
sexPclass_ogdata = data.groupby(['sex','pclass'])

# %%
sexPclass_ogdata['survived'].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
sexPclass_ogdata['survived'].mean().unstack().T
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
data.T.T.info() #destroy all dataTypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    object
#  2   sex       891 non-null    object
#  3   age       714 non-null    object
#  4   sibsp     891 non-null    object
#  5   parch     891 non-null    object
#  6   fare      891 non-null    object
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: object(9)
# memory usage: 62.8+ KB

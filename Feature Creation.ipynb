# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('files/titanic.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
#replacing missing values

# %%
data['age'].fillna(data['age'].mean(),inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
## (+)

# %%
data['sibsp']+ data['parch']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
data['Relative'] = data['sibsp'].add(data['parch']) #adding method is better

# %%
data.head(20)
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked deck  \
# 0          0       3    male  22.000000      1      0   7.2500        S  NaN
# 1          1       1  female  38.000000      1      0  71.2833        C    C
# 2          1       3  female  26.000000      0      0   7.9250        S  NaN
# 3          1       1  female  35.000000      1      0  53.1000        S    C
# 4          0       3    male  35.000000      0      0   8.0500        S  NaN
# 5          0       3    male  29.699118      0      0   8.4583        Q  NaN
# 6          0       1    male  54.000000      0      0  51.8625        S    E
# 7          0       3    male   2.000000      3      1  21.0750        S  NaN
# 8          1       3  female  27.000000      0      2  11.1333        S  NaN
# 9          1       2  female  14.000000      1      0  30.0708        C  NaN
# 10         1       3  female   4.000000      1      1  16.7000        S    G
# ...

# %%
##############

# %%
data_sale = pd.read_csv('files/sales.csv',index_col=0)

# %%
data_sale
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
data_sale['Mon'].add(data_sale['Thu'],fill_value=0)
# Out:
# Steven     34.0
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
data_sale['Bonus'] = [0.12,0.23,0.11,0.33]

# %%
data_sale
# Out:
#         Mon  Tue  Wed   Thu  Fri  Bonus
# Steven   34   27   15   NaN   33   0.12
# Mike     45    9   74  87.0   12   0.23
# Andi     17   33   54   8.0   29   0.11
# Paul     87   67   27  45.0    7   0.33

# %%
data_sale['Thu'].mul(data_sale['Bonus'],fill_value=0)
# Out:
# Steven     0.00
# Mike      20.01
# Andi       0.88
# Paul      14.85
# dtype: float64

# %%
data_sale.iloc[:,:-1].sum(axis=1).mul(data_sale['Bonus'])
# Out:
# Steven    13.08
# Mike      52.21
# Andi      15.51
# Paul      76.89
# dtype: float64

# %%
data_sale['Bonus_G']= data_sale.iloc[:,:-1].sum(axis=1).mul(data_sale['Bonus'])

# %%
data_sale
# Out:
#         Mon  Tue  Wed   Thu  Fri  Bonus  Bonus_G
# Steven   34   27   15   NaN   33   0.12    13.08
# Mike     45    9   74  87.0   12   0.23    52.21
# Andi     17   33   54   8.0   29   0.11    15.51
# Paul     87   67   27  45.0    7   0.33    76.89

# %%
################

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    Relative
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0

# %%
#age

# %%
1912- data['age']
# Out:
# 0      1890.000000
# 1      1874.000000
# 2      1886.000000
# 3      1877.000000
# 4      1877.000000
#           ...
# 886    1885.000000
# 887    1893.000000
# 888    1882.300882
# 889    1886.000000
# 890    1880.000000
# Name: age, Length: 891, dtype: float64

# %%
data['YoB'] = data['age'].sub(1912).mul(-1)

# %%
data
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
#      Relative          YoB
# ...

# %%
#dollar to Euro

# %%
euro_rate = 1.1

# %%
data['euro_fare'] = data['fare'].div(euro_rate)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    Relative     YoB  euro_fare
# 0         1  1890.0   6.590909
# 1         1  1874.0  64.803000
# 2         0  1886.0   7.204545
# 3         1  1877.0  48.272727
# 4         0  1877.0   7.318182

# %%
data.drop(columns=['sibsp','parch','deck','YoB','euro_fare'],inplace=True)

# %%
data.head()
# Out:
#    survived  pclass     sex   age     fare embarked  Relative
# 0         0       3    male  22.0   7.2500        S         1
# 1         1       1  female  38.0  71.2833        C         1
# 2         1       3  female  26.0   7.9250        S         0
# 3         1       1  female  35.0  53.1000        S         1
# 4         0       3    male  35.0   8.0500        S         0

# %%
################

# %%
data_sale
# Out:
#         Mon  Tue  Wed   Thu  Fri  Bonus  Bonus_G
# Steven   34   27   15   NaN   33   0.12    13.08
# Mike     45    9   74  87.0   12   0.23    52.21
# Andi     17   33   54   8.0   29   0.11    15.51
# Paul     87   67   27  45.0    7   0.33    76.89

# %%
fixed_cost = 4

# %%
data_sale.iloc[:,:-2].sub(fixed_cost,fill_value=0)
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   30   23   11  -4.0   29
# Mike     41    5   70  83.0    8
# Andi     13   29   50   4.0   25
# Paul     83   63   23  41.0    3

# %%
perc_bouns = 0.1

# %%
data_sale.iloc[:,:-2].mul(perc_bouns,fill_value=0)
# Out:
#         Mon  Tue  Wed  Thu  Fri
# Steven  3.4  2.7  1.5  0.0  3.3
# Mike    4.5  0.9  7.4  8.7  1.2
# Andi    1.7  3.3  5.4  0.8  2.9
# Paul    8.7  6.7  2.7  4.5  0.7

# %%
data_sale.iloc[:,:-2]
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
lot_size = 10
bonus_per_lot = 1.5

# %%
data_sale.iloc[:,:-2].floordiv(lot_size,fill_value=0).mul(bonus_per_lot).sum(axis=1)
# Out:
# Steven    13.5
# Mike      30.0
# Andi      16.5
# Paul      30.0
# dtype: float64
